# %%
from elasticsearch import Elasticsearch

# %%
es = Elasticsearch(
    "http://localhost:9200",
    basic_auth=("elastic", "changeme") 
)

# %%
es.indices.create(index="my_index", ignore=400)
# Out:
# /tmp/ipykernel_30222/4019947845.py:1: DeprecationWarning: Passing transport options in the API method is deprecated. Use 'Elasticsearch.options()' instead.
#   es.indices.create(index="my_index", ignore=400)
# ObjectApiResponse({'acknowledged': True, 'shards_acknowledged': True, 'index': 'my_index'})

# %%
doc = {
    "author": "kimchy",
    "text": "Elasticsearch: cool. bonsai cool.",
    "timestamp": "2024-01-24T14:12:12",
}

es.index(index="my_index", id=1, document=doc)
# Out:
# ObjectApiResponse({'_index': 'my_index', '_id': '1', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 0, '_primary_term': 1})

# %%
 resp = es.search(index="my_index", query={"query_string":{
                "query": "kimchy",
                "fields": ["author"], #fields you want to search
                "default_operator": "OR"
            }})
resp
# Out:
# ObjectApiResponse({'took': 4, 'timed_out': False, '_shards': {'total': 1, 'successful': 1, 'skipped': 0, 'failed': 0}, 'hits': {'total': {'value': 1, 'relation': 'eq'}, 'max_score': 0.2876821, 'hits': [{'_index': 'my_index', '_id': '1', '_score': 0.2876821, '_source': {'author': 'kimchy', 'text': 'Elasticsearch: cool. bonsai cool.', 'timestamp': '2024-01-24T14:12:12'}}]}})

# %%
results = search_elastic()  
print(results)
# Out:
# ---------------------------------------------------------------------------
# BadRequestError                           Traceback (most recent call last)
# Cell In[27], line 1
# ----> 1 results = search_elastic()
#       2 print(results)
#
# Cell In[26], line 7, in search_elastic()
#       1 def search_elastic():
#       2     {
#       3         "query": {
#       4                 "match_all": {}
#       5         }
#       6     }
# ----> 7     resp = es.search(index="my_index", query=query)
#       8     return resp
#
# File /usr/local/python/3.12.1/lib/python3.12/site-packages/elasticsearch/_sync/client/utils.py:414, in _rewrite_parameters.<locals>.wrapper.<locals>.wrapped(*args, **kwargs)
#     411         except KeyError:
#     412             pass
# --> 414 return api(*args, **kwargs)
#
# ...
